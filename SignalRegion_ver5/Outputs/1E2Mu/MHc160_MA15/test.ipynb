# %%
import pandas as pd

# %%
df = pd.read_csv("metrics.csv", index_col="index")

# %%
df
# Out:
#                       Unnamed: 0  auc_train  auc_valid  auc_test  \
# index
# lr-0.0001_hidden-192           0   0.696792   0.699717  0.724765
# lr-0.0001_hidden-128           1   0.523424   0.529396  0.419065
# lr-0.0005_hidden-128           2   0.870615   0.878718  0.866490
# lr-0.0005_hidden-64            3   0.757706   0.755560  0.749746
# lr-0.0005_hidden-192           4   0.877190   0.878358  0.878942
# lr-0.0005_hidden-256           5   0.894384   0.901585  0.893350
# lr-0.0001_hidden-256           6   0.612933   0.617599  0.620001
# lr-0.0001_hidden-64            7   0.315092   0.304212  0.317532
# lr-0.001_hidden-64             8   0.818649   0.822818  0.796950
# lr-0.001_hidden-128            9   0.867943   0.875248  0.885643
# lr-0.001_hidden-192           10   0.894367   0.894510  0.911383
# lr-0.005_hidden-64            11   0.914979   0.924673  0.922695
# lr-0.005_hidden-128           12   0.931299   0.941947  0.941441
# ...
